# %%
import seaborn as sns
import pandas as pd

# %%
data = [[1949,'Jan', 1213],[1900,'feb',122],[2000,'Jan',13]]

df = pd.DataFrame(data,columns=['year','month','passengers'])

print(df)
# Out:
#    year month  passengers
# 0  1949   Jan        1213
# 1  1900   feb         122
# 2  2000   Jan          13

# %%
sns.relplot(data=data, x ="year", y='month', hue='passengers', kind="line")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sns.relplot(data=data, x ="year", y='month', hue='passengers', kind="line")
#
# File ~/Projects/100million/venv/lib/python3.9/site-packages/seaborn/relational.py:862, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     859     kwargs.pop("ax")
#     861 # Use the full dataset to map the semantics
# --> 862 p = plotter(
#     863     data=data,
#     864     variables=plotter.get_semantics(locals()),
#     865     legend=legend,
#     866 )
#     867 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     868 p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# ...

# %%
x = ['Singe Insert', 'Batch Insert 400']
y = [1, 10000]

data = [100,200]
sns.relplot(data = data, x=x, y=y)
# Out:
# /Users/victorwu/Projects/100million/venv/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/victorwu/Projects/100million/venv/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/victorwu/Projects/100million/venv/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
